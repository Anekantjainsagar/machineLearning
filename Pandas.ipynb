# %% [markdown]
# <a href="https://colab.research.google.com/github/Anekantjainsagar/machineLearning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
myindex = ["Usa","Canada","Maxico"]

# %%
mydata = [1776, 1867, 2020]

# %%
myser = pd.Series(mydata, myindex)

# %%
myser
# Out:
# Usa       1776
# Canada    1867
# Maxico    2020
# dtype: int64

# %%
myser['Usa']
# Out:
# 1776

# %%
myser[0]
# Out:
# 1776

# %%
ages = {'sam':10, "aj":20}

# %%
pd.Series(ages)
# Out:
# sam    10
# aj     20
# dtype: int64

# %%
q1 = {'Japan': 80, "China": 450, "India":500, "Usa":200}
q2 = {'Brazil': 800, "China": 400, "India":5000, "Usa":80}

# %%
sales_q1 = pd.Series(q1)
sales_q2 = pd.Series(q2)

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    500
# Usa      200
# dtype: int64

# %%
sales_q2
# Out:
# Brazil     800
# China      400
# India     5000
# Usa         80
# dtype: int64

# %%
sales_q1["India"]
# Out:
# 500

# %%
sales_keys_q1 = sales_q1.keys()

# %%
sales_keys_q1
# Out:
# Index(['Japan', 'China', 'India', 'Usa'], dtype='object')

# %%
sales_keys_q1[0]
# Out:
# 'Japan'

# %%
sales_q1 / 100
# Out:
# Japan    0.8
# China    4.5
# India    5.0
# Usa      2.0
# dtype: float64

# %%
total_sales = sales_q1 + sales_q2

# %%
total_sales
# Out:
# Brazil       NaN
# China      850.0
# India     5500.0
# Japan        NaN
# Usa        280.0
# dtype: float64

# %%
total_sales = sales_q1.add(sales_q2,fill_value=0)

# %%
total_sales
# Out:
# Brazil     800.0
# China      850.0
# India     5500.0
# Japan       80.0
# Usa        280.0
# dtype: float64

# %%
sales_q1.dtype
# Out:
# dtype('int64')

# %%
total_sales.dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Dataframe
# Defination :- Group of Pandas Series
#
# table of coulumns and rows which can be restuructured and filtered

# %%
np.random.seed(101)
myData = np.random.randint(0,101,(4,3))

# %%
myData
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myIndex = ["CA","NY","AZ","TX"]

# %%
myCoulumns = ["JAN","FEB","MAR"]

# %%
df = pd.DataFrame(myData,myIndex,myCoulumns)

# %%
df
# Out:
#     JAN  FEB  MAR
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df['JAN']
# Out:
# CA    95
# NY    70
# AZ    75
# TX    40
# Name: JAN, dtype: int64

# %%
df["JAN"]["CA"]
# Out:
# 95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   JAN     4 non-null      int64
#  1   FEB     4 non-null      int64
#  2   MAR     4 non-null      int64
# dtypes: int64(3)
# memory usage: 300.0+ bytes

# %%
df = pd.read_csv('SMSPricing.csv')

# %%
df
# Out:
#       ISO   Country                                      Description  \
# 0     NaN   Unknown             SATELLITE Outbound SMS - Com4 Sweden
# 1     NaN   Unknown  SATELLITE Outbound SMS - Iridium Communications
# 2     NaN   Unknown                   SATELLITE Outbound SMS - Other
# 3      AD   Andorra                  ANDORRA Outbound SMS - Mobiland
# 4      AD   Andorra                     ANDORRA Outbound SMS - Other
# ...   ...       ...                                              ...
# 1087   ZM    Zambia                     ZAMBIA Outbound SMS - ZAMTEL
# 1088   ZW  Zimbabwe          ZIMBABWE Outbound SMS - Econet Wireless
# 1089   ZW  Zimbabwe                   ZIMBABWE Outbound SMS - NetOne
# 1090   ZW  Zimbabwe                    ZIMBABWE Outbound SMS - Other
# 1091   ZW  Zimbabwe                  ZIMBABWE Outbound SMS - Telecel
#
#       Price / msg
# 0          0.1000
# 1          0.1000
# 2          0.1000
# 3          0.1317
# 4          0.1317
# ...           ...
# ...

# %%
df.head()
# Out:
#    ISO  Country                                      Description  Price / msg
# 0  NaN  Unknown             SATELLITE Outbound SMS - Com4 Sweden       0.1000
# 1  NaN  Unknown  SATELLITE Outbound SMS - Iridium Communications       0.1000
# 2  NaN  Unknown                   SATELLITE Outbound SMS - Other       0.1000
# 3   AD  Andorra                  ANDORRA Outbound SMS - Mobiland       0.1317
# 4   AD  Andorra                     ANDORRA Outbound SMS - Other       0.1317

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ISO          1085 non-null   object
#  1   Country      1092 non-null   object
#  2   Description  1092 non-null   object
#  3   Price / msg  1092 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 34.2+ KB

# %%
df.columns
# Out:
# Index(['ISO', 'Country', 'Description', 'Price / msg'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1092, step=1)

# %%
df.tail(10)
# Out:
#      ISO       Country                              Description  Price / msg
# 1082  ZA  South Africa        SOUTH AFRICA Outbound SMS - Other       0.0284
# 1083  ZA  South Africa      SOUTH AFRICA Outbound SMS - Vodacom       0.0284
# 1084  ZM        Zambia             ZAMBIA Outbound SMS - Airtel       0.2683
# 1085  ZM        Zambia                ZAMBIA Outbound SMS - MTN       0.2683
# 1086  ZM        Zambia              ZAMBIA Outbound SMS - Other       0.2683
# 1087  ZM        Zambia             ZAMBIA Outbound SMS - ZAMTEL       0.2683
# 1088  ZW      Zimbabwe  ZIMBABWE Outbound SMS - Econet Wireless       0.1407
# 1089  ZW      Zimbabwe           ZIMBABWE Outbound SMS - NetOne       0.1407
# 1090  ZW      Zimbabwe            ZIMBABWE Outbound SMS - Other       0.1407
# 1091  ZW      Zimbabwe          ZIMBABWE Outbound SMS - Telecel       0.1407

# %%
df.describe()
# Out:
#        Price / msg
# count  1092.000000
# mean      0.142098
# std       0.104747
# min       0.007900
# 25%       0.071500
# 50%       0.109100
# 75%       0.181000
# max       0.709600

# %%
df.transpose()
# Out:
#                                              0     \
# ISO                                           NaN
# Country                                   Unknown
# Description  SATELLITE Outbound SMS - Com4 Sweden
# Price / msg                                   0.1
#
#                                                         1     \
# ISO                                                      NaN
# Country                                              Unknown
# Description  SATELLITE Outbound SMS - Iridium Communications
# Price / msg                                              0.1
#
#                                        2                                3     \
# ISO                                     NaN                               AD
# Country                             Unknown                          Andorra
# Description  SATELLITE Outbound SMS - Other  ANDORRA Outbound SMS - Mobiland
# Price / msg                             0.1                           0.1317
#
# ...

# %%
df.columns
# Out:
# Index(['ISO', 'Country', 'Description', 'Price / msg'], dtype='object')

# %%
list = ['ISO',"Country","Price / msg"]

# %%
df[list]
# Out:
#       ISO   Country  Price / msg
# 0     NaN   Unknown       0.1000
# 1     NaN   Unknown       0.1000
# 2     NaN   Unknown       0.1000
# 3      AD   Andorra       0.1317
# 4      AD   Andorra       0.1317
# ...   ...       ...          ...
# 1087   ZM    Zambia       0.2683
# 1088   ZW  Zimbabwe       0.1407
# 1089   ZW  Zimbabwe       0.1407
# 1090   ZW  Zimbabwe       0.1407
# 1091   ZW  Zimbabwe       0.1407
#
# [1092 rows x 3 columns]

# %%
df['origin'] = "India"

# %%
df
# Out:
#       ISO   Country                                      Description  \
# 0     NaN   Unknown             SATELLITE Outbound SMS - Com4 Sweden
# 1     NaN   Unknown  SATELLITE Outbound SMS - Iridium Communications
# 2     NaN   Unknown                   SATELLITE Outbound SMS - Other
# 3      AD   Andorra                  ANDORRA Outbound SMS - Mobiland
# 4      AD   Andorra                     ANDORRA Outbound SMS - Other
# ...   ...       ...                                              ...
# 1087   ZM    Zambia                     ZAMBIA Outbound SMS - ZAMTEL
# 1088   ZW  Zimbabwe          ZIMBABWE Outbound SMS - Econet Wireless
# 1089   ZW  Zimbabwe                   ZIMBABWE Outbound SMS - NetOne
# 1090   ZW  Zimbabwe                    ZIMBABWE Outbound SMS - Other
# 1091   ZW  Zimbabwe                  ZIMBABWE Outbound SMS - Telecel
#
#       Price / msg origin
# 0          0.1000  India
# 1          0.1000  India
# 2          0.1000  India
# 3          0.1317  India
# ...

# %%
df["Price / msg"] = np.round(df['Price / msg'], 2)

# %%
df.drop("origin",1)
# Out:
# <ipython-input-63-644f5bdf64ce>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop("origin",1)
#       ISO   Country                                      Description  \
# 0     NaN   Unknown             SATELLITE Outbound SMS - Com4 Sweden
# 1     NaN   Unknown  SATELLITE Outbound SMS - Iridium Communications
# 2     NaN   Unknown                   SATELLITE Outbound SMS - Other
# 3      AD   Andorra                  ANDORRA Outbound SMS - Mobiland
# 4      AD   Andorra                     ANDORRA Outbound SMS - Other
# ...   ...       ...                                              ...
# 1087   ZM    Zambia                     ZAMBIA Outbound SMS - ZAMTEL
# 1088   ZW  Zimbabwe          ZIMBABWE Outbound SMS - Econet Wireless
# 1089   ZW  Zimbabwe                   ZIMBABWE Outbound SMS - NetOne
# 1090   ZW  Zimbabwe                    ZIMBABWE Outbound SMS - Other
# ...

# %%
df
# Out:
#       ISO   Country                                      Description  \
# 0     NaN   Unknown             SATELLITE Outbound SMS - Com4 Sweden
# 1     NaN   Unknown  SATELLITE Outbound SMS - Iridium Communications
# 2     NaN   Unknown                   SATELLITE Outbound SMS - Other
# 3      AD   Andorra                  ANDORRA Outbound SMS - Mobiland
# 4      AD   Andorra                     ANDORRA Outbound SMS - Other
# ...   ...       ...                                              ...
# 1087   ZM    Zambia                     ZAMBIA Outbound SMS - ZAMTEL
# 1088   ZW  Zimbabwe          ZIMBABWE Outbound SMS - Econet Wireless
# 1089   ZW  Zimbabwe                   ZIMBABWE Outbound SMS - NetOne
# 1090   ZW  Zimbabwe                    ZIMBABWE Outbound SMS - Other
# 1091   ZW  Zimbabwe                  ZIMBABWE Outbound SMS - Telecel
#
#       Price / msg origin
# 0            0.10  India
# 1            0.10  India
# 2            0.10  India
# 3            0.13  India
# ...

# %%
df.shape
# Out:
# (1092, 5)

# %%
df.head()
# Out:
#    ISO  Country                                      Description  Price / msg  \
# 0  NaN  Unknown             SATELLITE Outbound SMS - Com4 Sweden         0.10
# 1  NaN  Unknown  SATELLITE Outbound SMS - Iridium Communications         0.10
# 2  NaN  Unknown                   SATELLITE Outbound SMS - Other         0.10
# 3   AD  Andorra                  ANDORRA Outbound SMS - Mobiland         0.13
# 4   AD  Andorra                     ANDORRA Outbound SMS - Other         0.13
#
#   origin
# 0  India
# 1  India
# 2  India
# 3  India
# 4  India

# %%
df['Price / msg'] > 0.1
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1087     True
# 1088     True
# 1089     True
# 1090     True
# 1091     True
# Name: Price / msg, Length: 1092, dtype: bool

# %%
df[df['Price / msg'] < 0.07]
# Out:
#      ISO       Country                          Description  Price / msg  \
# 53    AU     Australia           AUSTRALIA Outbound SMS - 3         0.05
# 54    AU     Australia  AUSTRALIA Outbound SMS - Lycamobile         0.05
# 55    AU     Australia       AUSTRALIA Outbound SMS - Optus         0.05
# 56    AU     Australia       AUSTRALIA Outbound SMS - Other         0.05
# 57    AU     Australia     AUSTRALIA Outbound SMS - Pivotel         0.05
# ...   ..           ...                                  ...          ...
# 1079  ZA  South Africa      SOUTH AFRICA Outbound SMS - 8ta         0.03
# 1080  ZA  South Africa   SOUTH AFRICA Outbound SMS - Cell C         0.03
# 1081  ZA  South Africa      SOUTH AFRICA Outbound SMS - MTN         0.03
# 1082  ZA  South Africa    SOUTH AFRICA Outbound SMS - Other         0.03
# 1083  ZA  South Africa  SOUTH AFRICA Outbound SMS - Vodacom         0.03
#
#      origin
# 53    India
# 54    India
# 55    India
# 56    India
# 57    India
# ...

# %%
df[(df['Country']!="Unknown") & (df['Price / msg'] < 0.02)]
# Out:
#      ISO        Country                                Description  \
# 151   CA         Canada        CANADA Local Outbound SMS -  Telus
# 152   CA         Canada  CANADA Local Outbound SMS - Bell & Virgin
# 153   CA         Canada          CANADA Local Outbound SMS - Other
# 154   CA         Canada         CANADA Local Outbound SMS - Rogers
# 1032  US  United States       UNITED STATES Inbound SMS - T-Mobile
# 1033  US  United States          UNITED STATES Outbound SMS - AT&T
# 1034  US  United States         UNITED STATES Outbound SMS - Other
# 1035  US  United States      UNITED STATES Outbound SMS - T-Mobile
#
#       Price / msg origin
# 151          0.01  India
# 152          0.01  India
# 153          0.01  India
# 154          0.01  India
# 1032         0.01  India
# 1033         0.01  India
# 1034         0.01  India
# 1035         0.01  India

# %%
list = ["US","IN"]
bool_is_in = df["ISO"].isin(list)

# %%
df[bool_is_in]
# Out:
#      ISO        Country                               Description  \
# 454   IN          India               INDIA Outbound SMS - Aircel
# 455   IN          India               INDIA Outbound SMS - Airtel
# 456   IN          India                 INDIA Outbound SMS - BSNL
# 457   IN          India  INDIA Outbound SMS - Etisalat DB Telecom
# 458   IN          India        INDIA Outbound SMS - Idea Cellular
# 459   IN          India          INDIA Outbound SMS - Loop Mobile
# 460   IN          India                 INDIA Outbound SMS - MTNL
# 461   IN          India                  INDIA Outbound SMS - MTS
# 462   IN          India                INDIA Outbound SMS - Other
# 463   IN          India          INDIA Outbound SMS - Ping Mobile
# 464   IN          India             INDIA Outbound SMS - Reliance
# 465   IN          India                INDIA Outbound SMS - S Tel
# 466   IN          India          INDIA Outbound SMS - Tata DoCoMo
# ...
